# %%
# create data frame 

_data = [(1,"Suresh",5000),
         (2,"Ganesh",6000),
         (3,"Ramesh",7000),
         (4,"Rajesh",8000)]

_schemma = "userid int,name string,salary int"

df = spark.createDataFrame(data=_data,schema=_schemma)
